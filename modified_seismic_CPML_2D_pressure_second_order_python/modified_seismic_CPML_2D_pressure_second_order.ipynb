# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
import imageio
import subprocess
import os
from modified_seismic_CPML_2D_pressure_second_order_functions import *

# %%
# Directory to save the images
output_dir = 'results'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Compile the Fortran file
compile_command = ["gfortran", "-o", "seismic_pressure_model", "seismic_CPML_2D_pressure_second_order.f90"]

try:
    print("Compiling the Fortran file...")
    subprocess.run(compile_command, check=True)
    print("Compilation successful!")
except subprocess.CalledProcessError as e:
    print(f"Compilation failed: {e}")
    # Exit early if compilation fails
    raise SystemExit("Exiting due to compilation error.")

# Run the compiled executable
run_command = ["./seismic_pressure_model"]

try:
    print("Running the executable...")
    result = subprocess.run(run_command, check=True, capture_output=True, text=True)
    print("Execution successful!\n")
    print(result.stdout)
except subprocess.CalledProcessError as e:
    print(f"Execution failed: {e}")
    print(e.stderr)
# Out:
# Compiling the Fortran file...
# Compilation successful!
# Running the executable...
# Execution successful!
#
#  JSOURCE =           10
#
#  2D acoustic finite-difference code in pressure formulation with C-PML
#
#
#  NX =          300
#  NY =          300
#
#  size of the model along X =    1495.0000000000000
#  size of the model along Y =    1495.0000000000000
#
#  Total number of grid points =        90000
#
#  d0_x =    1381.5510557964271
#  d0_y =    1381.5510557964271
#
#  There are            1  receivers
#
#  receiver            1  x_target,y_target =    800.00000000000000        750.00000000000000
#  closest grid point found at distance    0.0000000000000000       in i,j =          161         151
#
#  Courant number is    7.0710676332352770E-002
#
#  Time step #            5  out of         8001
#  Time:    3.99999990E-04  seconds
#  Max absolute value of pressure =    2.2811259301688223
#
#  Time step #          125  out of         8001
#  Time:    1.23999994E-02  seconds
#  Max absolute value of pressure =    4741.2536519044661
#
#  Time step #          250  out of         8001
#  Time:    2.48999987E-02  seconds
#  Max absolute value of pressure =    212487.14787337335
#
#  Time step #          375  out of         8001
#  Time:    3.73999998E-02  seconds
#  Max absolute value of pressure =    2385007.2652244796
#
#  Time step #          500  out of         8001
#  Time:    4.98999991E-02  seconds
#  Max absolute value of pressure =    5375370.1307097273
#
#  Time step #          625  out of         8001
#  Time:    6.23999983E-02  seconds
#  Max absolute value of pressure =    5381139.7086810246
#
#  Time step #          750  out of         8001
#  Time:    7.49000013E-02  seconds
#  Max absolute value of pressure =    5480966.9466276476
#
#  Time step #          875  out of         8001
#  Time:    8.73999968E-02  seconds
#  Max absolute value of pressure =    5502016.2576630823
#
#  Time step #         1000  out of         8001
#  Time:    9.98999998E-02  seconds
#  Max absolute value of pressure =    5509536.8488394683
#
#  Time step #         1125  out of         8001
#  Time:   0.112399995      seconds
#  Max absolute value of pressure =    5529441.1865029074
#
#  Time step #         1250  out of         8001
#  Time:   0.124899998      seconds
#  Max absolute value of pressure =    5584803.5508171869
#
#  Time step #         1375  out of         8001
#  Time:   0.137400001      seconds
#  Max absolute value of pressure =    5622330.1735559301
#
#  Time step #         1500  out of         8001
#  Time:   0.149899989      seconds
#  Max absolute value of pressure =    5641169.5691418126
#
#  Time step #         1625  out of         8001
#  Time:   0.162399992      seconds
#  Max absolute value of pressure =    5642855.8334277067
#
#  Time step #         1750  out of         8001
#  Time:   0.174899995      seconds
#  Max absolute value of pressure =    5702343.3166847806
#
#  Time step #         1875  out of         8001
#  Time:   0.187399998      seconds
#  Max absolute value of pressure =    5748345.5009900713
#
#  Time step #         2000  out of         8001
#  Time:   0.199900001      seconds
#  Max absolute value of pressure =    5775282.1842543557
#
#  Time step #         2125  out of         8001
#  Time:   0.212399989      seconds
#  Max absolute value of pressure =    5783475.7106793178
#
#  Time step #         2250  out of         8001
#  Time:   0.224899992      seconds
#  Max absolute value of pressure =    5813703.7289203042
#
#  Time step #         2375  out of         8001
#  Time:   0.237399995      seconds
#  Max absolute value of pressure =    8885102.4668403789
#
#  Time step #         2500  out of         8001
#  Time:   0.249899998      seconds
#  Max absolute value of pressure =    10181849.863699976
#
#  Time step #         2625  out of         8001
#  Time:   0.262400001      seconds
#  Max absolute value of pressure =    10068321.982056864
#
#  Time step #         2750  out of         8001
#  Time:   0.274899989      seconds
#  Max absolute value of pressure =    9977455.3340383954
#
#  Time step #         2875  out of         8001
#  Time:   0.287400007      seconds
#  Max absolute value of pressure =    9813732.1021104399
#
#  Time step #         3000  out of         8001
#  Time:   0.299899995      seconds
#  Max absolute value of pressure =    9656558.8391551059
#
#  Time step #         3125  out of         8001
#  Time:   0.312399983      seconds
#  Max absolute value of pressure =    9534367.7339581419
#
#  Time step #         3250  out of         8001
#  Time:   0.324900001      seconds
#  Max absolute value of pressure =    9333419.8745078202
#
#  Time step #         3375  out of         8001
#  Time:   0.337399989      seconds
#  Max absolute value of pressure =    9165568.2165314481
#
#  Time step #         3500  out of         8001
#  Time:   0.349899977      seconds
#  Max absolute value of pressure =    9053747.8766127042
#
#  Time step #         3625  out of         8001
#  Time:   0.362399995      seconds
#  Max absolute value of pressure =    8951614.5794319268
#
#  Time step #         3750  out of         8001
#  Time:   0.374899983      seconds
#  Max absolute value of pressure =    8860321.0841767807
#
#  Time step #         3875  out of         8001
#  Time:   0.387400001      seconds
#  Max absolute value of pressure =    8797801.8095404729
#
#  Time step #         4000  out of         8001
#  Time:   0.399899989      seconds
#  Max absolute value of pressure =    8764106.8233277146
#
#  Time step #         4125  out of         8001
#  Time:   0.412399977      seconds
#  Max absolute value of pressure =    8786047.8554455116
#
#  Time step #         4250  out of         8001
#  Time:   0.424899995      seconds
#  Max absolute value of pressure =    8798426.1004810017
#
#  Time step #         4375  out of         8001
#  Time:   0.437399983      seconds
#  Max absolute value of pressure =    8786054.0637867525
#
#  Time step #         4500  out of         8001
#  Time:   0.449900001      seconds
#  Max absolute value of pressure =    8737635.2184778210
#
#  Time step #         4625  out of         8001
#  Time:   0.462399989      seconds
#  Max absolute value of pressure =    8765481.0918474961
#
#  Time step #         4750  out of         8001
#  Time:   0.474899977      seconds
#  Max absolute value of pressure =    8755595.0470755659
#
#  Time step #         4875  out of         8001
#  Time:   0.487399995      seconds
#  Max absolute value of pressure =    8701885.3307910841
#
#  Time step #         5000  out of         8001
#  Time:   0.499899983      seconds
#  Max absolute value of pressure =    8650357.7906386014
#
#  Time step #         5125  out of         8001
#  Time:   0.512399971      seconds
#  Max absolute value of pressure =    8638238.2910165619
#
#  Time step #         5250  out of         8001
#  Time:   0.524899960      seconds
#  Max absolute value of pressure =    8580765.2507192548
#
#  Time step #         5375  out of         8001
#  Time:   0.537400007      seconds
#  Max absolute value of pressure =    8472816.1495050397
#
#  Time step #         5500  out of         8001
#  Time:   0.549899995      seconds
#  Max absolute value of pressure =    8448717.7366852369
#
#  Time step #         5625  out of         8001
#  Time:   0.562399983      seconds
#  Max absolute value of pressure =    8393821.6172250696
#
#  Time step #         5750  out of         8001
#  Time:   0.574899971      seconds
#  Max absolute value of pressure =    8292909.6810186887
#
#  Time step #         5875  out of         8001
#  Time:   0.587399960      seconds
#  Max absolute value of pressure =    8200812.5576084657
#
#  Time step #         6000  out of         8001
#  Time:   0.599900007      seconds
#  Max absolute value of pressure =    8159220.7649327517
#
#  Time step #         6125  out of         8001
#  Time:   0.612399995      seconds
#  Max absolute value of pressure =    8075435.3906269055
#
#  Time step #         6250  out of         8001
#  Time:   0.624899983      seconds
#  Max absolute value of pressure =    7951507.5625761338
#
#  Time step #         6375  out of         8001
#  Time:   0.637399971      seconds
#  Max absolute value of pressure =    7897129.7412171969
#
#  Time step #         6500  out of         8001
#  Time:   0.649899960      seconds
#  Max absolute value of pressure =    5865508.1439742232
#
#  Time step #         6625  out of         8001
#  Time:   0.662400007      seconds
#  Max absolute value of pressure =    2683353.0881913910
#
#  Time step #         6750  out of         8001
#  Time:   0.674899995      seconds
#  Max absolute value of pressure =    1993095.6541378945
#
#  Time step #         6875  out of         8001
#  Time:   0.687399983      seconds
#  Max absolute value of pressure =    1488265.4921940805
#
#  Time step #         7000  out of         8001
#  Time:   0.699899971      seconds
#  Max absolute value of pressure =    1451091.2702235088
#
#  Time step #         7125  out of         8001
#  Time:   0.712399960      seconds
#  Max absolute value of pressure =    827176.94200631313
#
#  Time step #         7250  out of         8001
#  Time:   0.724900007      seconds
#  Max absolute value of pressure =    217238.98810417854
#
#  Time step #         7375  out of         8001
#  Time:   0.737399995      seconds
#  Max absolute value of pressure =    155633.62377449256
#
#  Time step #         7500  out of         8001
#  Time:   0.749899983      seconds
#  Max absolute value of pressure =    138463.04723006033
#
#  Time step #         7625  out of         8001
#  Time:   0.762399971      seconds
#  Max absolute value of pressure =    113135.76279381497
#
#  Time step #         7750  out of         8001
#  Time:   0.774899960      seconds
#  Max absolute value of pressure =    102195.90913548692
#
#  Time step #         7875  out of         8001
#  Time:   0.787400007      seconds
#  Max absolute value of pressure =    96625.044528700862
#
#  Time step #         8000  out of         8001
#  Time:   0.799899995      seconds
#  Max absolute value of pressure =    90726.886702358985
#
#
#  End of the simulation

# %% [markdown]
# Time: 17 s

# %%
# Ruta al archivo de datos
file_path = 'results/kappa_unrelaxed.txt'

# Leer los datos del archivo
data = np.loadtxt(file_path)

# Extraer los índices y valores
i_indices = data[:, 0].astype(int)
j_indices = data[:, 1].astype(int)
values = data[:, 2]

# Determinar el tamaño de la matriz
NX = int(np.max(i_indices))
NY = int(np.max(j_indices))

# Crear la matriz de valores
kappa_matrix = np.zeros((NX, NY))

# Rellenar la matriz con los datos
for i, j, value in zip(i_indices, j_indices, values):
    kappa_matrix[i-1, j-1] = value  # Restar 1 si los índices en el archivo son basados en 1

# %%
 

# Cargar los datos del archivo .txt
its = [1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000, 5500, 6000, 6500, 7000, 8000]

# Inicializar los valores globales de vmin y vmax
global_vmin = float('inf')
global_vmax = float('-inf')

# Calcular los valores globales de vmin y vmax
for it in its:
    data = np.loadtxt(f'{output_dir}/pressure_future_{it}.txt')
    pressure = data[:, 2]
    global_vmin = min(global_vmin, np.min(pressure))
    global_vmax = max(global_vmax, np.max(pressure))

# Save the images
for i, it in enumerate(its):
    # Cargar los datos correspondientes
    data = np.loadtxt(f'{output_dir}/pressure_future_{it}.txt')
    x = data[:, 0]
    y = data[:, 1]
    pressure = data[:, 2]

    # Reorganizar los valores de presión en una matriz
    wavefields = pressure.reshape((len(np.unique(y)), len(np.unique(x))))

    # Definir los límites de los ejes
    x_min, x_max = np.min(x), np.max(x)
    y_min, y_max = np.min(y), np.max(y)

    plt.figure()
    plt.title(f'Time: {0.0001*it:.2f} s', fontsize=10)
    plt.xlabel('Distance (m)', fontsize=10)
    plt.ylabel('Depth (m)', fontsize=10)

    # Mostrar el mapa de kappa en gris transparente
    normalized_kappa = kappa_matrix / np.max(kappa_matrix)
    plt.imshow(normalized_kappa, extent=[x_min, x_max, y_min, y_max], aspect=1, cmap='gist_yarg', alpha=0.5, vmin=0, vmax=1)

    # Mostrar el campo de presión sobre el mapa de kappa
    im = plt.imshow(wavefields, extent=[x_min, x_max, y_min, y_max], aspect=1, cmap='seismic', alpha=0.8, vmin=-global_vmax, vmax=global_vmax)

    # Añadir la barra de color con los valores globales
    cbar = plt.colorbar(im)
    cbar.set_label('Pressure')

    # Guardar la figura individualmente con un nombre único
    plt.savefig(f'{output_dir}/wavefields_{it}.png')
    plt.close()

# Create the GIF
images = []
for it in its:
    images.append(imageio.imread(f'{output_dir}/wavefields_{it}.png'))

# Set the frames per second (fps) to control the speed of the GIF
imageio.mimsave(f'pressure_evolution.gif', images, fps=2)
# Out:
# /tmp/ipykernel_25218/1609061751.py:53: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   images.append(imageio.imread(f'{output_dir}/wavefields_{it}.png'))
